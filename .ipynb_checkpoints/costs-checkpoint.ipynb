# %%
import pandas as pd

# %%
# !ls
# Out:
# Crops unit cost.csv                crops.csv
# Tulare Ag.ipynb                    crops.ipynb
# Tulare ag production 2010-2020.csv data
# costs.ipynb                        docs

# %%
df = pd.read_csv("Crops unit cost.csv")

# %%
df.head()
# Out:
#    Year  alfalfa  almond  orange  pomegranates  tangerine  grape (table)  \
# 0  2010      124    3460    1358          1510       1040           1650
# 1  2011      250    3700    1277          1670       1380           1704
# 2  2012      217    5170    1332          1280       1510           2070
# 3  2013      233    6040    1290          1120       1820           1650
# 4  2014      222    8050    1718           987       1900           1564
#
#    grape (raisin)
# 0            3212
# 1            3245
# 2            3967
# 3            3501
# 4            3790

# %%
df.dtypes
# Out:
# Year              int64
# alfalfa           int64
# almond            int64
# orange            int64
# pomegranates      int64
# tangerine         int64
# grape (table)     int64
# grape (raisin)    int64
# dtype: object

# %%
df['% change alfalfa']=df['alfalfa'].pct_change()*100
df['% change almond']=df['almond'].pct_change()*100
df['% change orange']=df['orange'].pct_change()*100
df['% change pomegranates']=df['pomegranates'].pct_change()*100
df['% change tangerine']=df['tangerine'].pct_change()*100
df['% change grape (table)']=df['grape (table)'].pct_change()*100
df['% change grape (raisin)']=df['grape (raisin)'].pct_change()*100

# %%
df
# Out:
#     Year  alfalfa  almond  orange  pomegranates  tangerine  grape (table)  \
# 0   2010      124    3460    1358          1510       1040           1650
# 1   2011      250    3700    1277          1670       1380           1704
# 2   2012      217    5170    1332          1280       1510           2070
# 3   2013      233    6040    1290          1120       1820           1650
# 4   2014      222    8050    1718           987       1900           1564
# 5   2015      170    7250    1394          1100       1490           1524
# 6   2016      154    4400    1331           671       1770           1535
# 7   2017      191    4640    1331          1400       1740           2104
# 8   2018      203    4470    1386           916       1510           1745
# 9   2019      207    4940    1349          3160       1260           1732
# 10  2020      208    3460    1496          1280        962           1839
#
#     grape (raisin)  % change alfalfa  % change almond  % change orange  \
# ...
