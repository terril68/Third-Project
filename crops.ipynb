# %%
import pandas as pd
import altair as alt

# %%
# !ls
# Out:
# Tulare Ag.ipynb                    crops.ipynb
# Tulare ag production 2010-2020.csv data
# crops.csv                          docs

# %%
df = pd.read_csv("crops.csv")

# %%
df.head(20)
# Out:
#      index     crop   amount
# 0   yr2010  Alfalfa   803000
# 1   yr2011  Alfalfa   821000
# 2   yr2012  Alfalfa  1117000
# 3   yr2013  Alfalfa   840000
# 4   yr2014  Alfalfa  1104000
# 5   yr2015  Alfalfa  1669000
# 6   yr2016  Alfalfa  1128000
# 7   yr2017  Alfalfa   967000
# 8   yr2018  Alfalfa   980000
# 9   yr2019  Alfalfa   870000
# 10  yr2020  Alfalfa   759000
# 11  yr2010  Almonds    28400
# 12  yr2011  Almonds    34700
# 13  yr2012  Almonds    34800
# 14  yr2013  Almonds    40800
# 15  yr2014  Almonds    48700
# 16  yr2015  Almonds    43000
# 17  yr2016  Almonds    66400
# 18  yr2017  Almonds    68700
# 19  yr2018  Almonds    67300

# %%
alt.Chart(df, title='What is the most produced crop?').mark_area().encode(
    x='index:N',
    y='amount:Q').facet(facet='crop:N',columns=2)
# Out:
# alt.FacetChart(...)
